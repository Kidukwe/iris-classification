# %%
import pandas as pd

# %%
acc_lr = 0.9111
acc_dt = 1.0
acc_rf = 1.0
results = pd.DataFrame({
    'Model': ['LogisticRegression', 'Decision Tree','Random Forest'],
    'Accuracy': [acc_lr, acc_dt, acc_rf]
})
display(results)
# Out:
#                 Model  Accuracy
# 0  LogisticRegression    0.9111
# 1       Decision Tree    1.0000
# 2       Random Forest    1.0000
